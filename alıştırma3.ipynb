# %%
class Araba:

  def __init__(self, marka, model, hiz=0):
    self.marka = marka
    self.model = model
    self.hiz = hiz

  def hizlandir(self, artis):
    self.hiz += artis

  def bilgi_goster(self):
    print(f"Araç Bilgisi -> Marka: {self.marka}, Model: {self.model}, Hız: {self.hiz} km/s")


araba1 = Araba("Toyota", "Corolla", 50)
araba1.bilgi_goster()
araba1.hizlandir(30)
araba1.bilgi_goster()

print("-" * 40)
# Out:
# Araç Bilgisi -> Marka: Toyota, Model: Corolla, Hız: 50 km/s
# Araç Bilgisi -> Marka: Toyota, Model: Corolla, Hız: 80 km/s
# ----------------------------------------

# %%
class Dikdortgen:

  def __init__(self, uzunluk, genislik):
    self.uzunluk = uzunluk
    self.genislik = genislik

  def alan_hesapla(self):
    return self.uzunluk * self.genislik

  def cevre_hesapla(self):
    return 2 * (self.uzunluk + self.genislik)


d = Dikdortgen(10, 5)
print(f"Alan: {d.alan_hesapla()}")
print(f"Çevre: {d.cevre_hesapla()}")

print("-" * 40)
# Out:
# Alan: 50
# Çevre: 30
# ----------------------------------------

# %%
class Kitap:

  def __init__(self, ad, yazar, sayfa_sayisi):
    self.ad = ad
    self.yazar = yazar
    self.sayfa_sayisi = sayfa_sayisi

  def ozet(self):
    return f"{self.ad} - {self.yazar} ({self.sayfa_sayisi} sayfa)"


kitap1 = Kitap("Suç ve Ceza", "Dostoyevski", 671)
print(kitap1.ozet())
# Out:
# Suç ve Ceza - Dostoyevski (671 sayfa)
